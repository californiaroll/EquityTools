# %%
import sys, os

# %%
sys.path.append(os.path.abspath(".."))

# %%
import pandas as pd

# %%
import yfinance as yf

# %%
import equitytools_local.technical_indicators as technical_indicators_tools
import equitytools_local.data as datatools
import equitytools_local.plotting as plottools

# %%
from importlib import reload
reload(datatools)
# Out:
# <module 'equitytools_local.data' from 'C:\\Users\\jonsw\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\Scripts\\equitytools_local\\data.py'>

# %%
reload(plottools)
# Out:
# <module 'equitytools_local.plotting' from 'C:\\Users\\jonsw\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\Scripts\\equitytools_local\\plotting.py'>

# %%
reload(technical_indicators_tools)
# Out:
# <module 'equitytools_local.technical_indicators' from 'C:\\Users\\jonsw\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\Scripts\\equitytools_local\\technical_indicators.py'>

# %%
df = yf.download("NVDA", period="1y")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df = technical_indicators_tools.add_all_indicators(df)

# %%
plottools.plot_price_with_rsi(df, "NVDA")

# %%
plottools.plot_price_with_bollinger(df, "nvda")
