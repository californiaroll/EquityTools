# %%
import yfinance as yf

# %%
import pandas as pd

# %%
import sys, os

# %%
sys.path.append(os.path.abspath(".."))

# %%
import equitytools_local.data as datatools

# %%
from importlib import reload
reload(datatools)
# Out:
# <module 'equitytools_local.data' from 'C:\\Users\\jonsw\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python311\\Scripts\\equitytools_local\\data.py'>

# %% [markdown]
# # Example usage

# %%
(calls_df, puts_df) = datatools.get_options_data("AAPL")
# Out:
# Data saved to CSV for AAPL (2026-02-18).

# %%
print(calls_df.head(10))
# Out:
#         contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0  AAPL260218C00210000 2026-02-13 20:57:40+00:00   210.0      46.27  44.60
# 1  AAPL260218C00215000 2026-02-13 20:57:40+00:00   215.0      41.34  39.70
# 2  AAPL260218C00225000 2026-02-09 20:52:45+00:00   225.0      50.12  29.65
# 3  AAPL260218C00230000 2026-02-13 19:57:14+00:00   230.0      28.75  24.85
# 4  AAPL260218C00242500 2026-02-11 19:02:42+00:00   242.5      36.60  13.40
# 5  AAPL260218C00245000 2026-02-13 20:22:47+00:00   245.0      12.68  11.00
# 6  AAPL260218C00250000 2026-02-13 20:57:02+00:00   250.0       7.15   7.00
# 7  AAPL260218C00255000 2026-02-13 20:59:44+00:00   255.0       3.51   3.45
# 8  AAPL260218C00257500 2026-02-13 20:59:58+00:00   257.5       2.16   2.16
# 9  AAPL260218C00260000 2026-02-13 20:59:57+00:00   260.0       1.25   1.24
#
#      ask     change  percentChange  volume  openInterest  impliedVolatility  \
# ...

# %%
assert len(calls_df.index) > 0

# %%
assert len(puts_df.index) > 0
