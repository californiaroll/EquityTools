# %%
def reload_equitytools():
    import sys
    sys.modules.pop("test_data", None)
    import tests.test_data

# %%
reload_equitytools()

# %%
import pytest as test

# %%
test.main(["-q"])
# Out:
# ......                                                                                                           [100%]
# 6 passed in 0.08s
# <ExitCode.OK: 0>
