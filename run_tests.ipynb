# %%
def reload_equitytools():
    import sys
    sys.modules.pop("test_data", None)
    sys.modules.pop("test_modeling", None)
    sys.modules.pop("test_plotting", None)
    import tests.test_data
    import tests.test_modeling
    import tests.test_plotting

# %%
reload_equitytools()

# %%
import pytest as test

# %%
test.main(["-q"])
# Out:
# ........................F                                                                                        [100%]
# ====================================================== FAILURES =======================================================
# ___________________________________ test_plot_volatility_calls_matplotlib_correctly ___________________________________
#
#     def test_plot_volatility_calls_matplotlib_correctly():
#         # Create a small fake DataFrame with a datetime index
#         dates = pd.date_range(start="2024-01-01", periods=3, freq="D")
#         df = pd.DataFrame({"volatility": [0.1, 0.2, 0.15]}, index=dates)
#
#         with patch("equitytools_local.plotting.plt.figure") as mock_fig, \
#              patch("equitytools_local.plotting.plt.plot") as mock_plot, \
#              patch("equitytools_local.plotting.plt.title") as mock_title, \
#              patch("equitytools_local.plotting.plt.xlabel") as mock_xlabel, \
# ...
